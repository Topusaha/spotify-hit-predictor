# %% [markdown]
# ### Creating a base model for Decision Tree and Linear Regression

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_predict, cross_val_score, learning_curve
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression 
from sklearn.tree import DecisionTreeRegressor

# %%
data_path = 'playlist_2010to2022.csv'
playlist_df = pd.read_csv(data_path)

# Display the first few rows of the dataframe
playlist_df.head()
# Out:
#                                         playlist_url  year  \
# 0  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 1  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 2  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 3  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 4  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
#
#                  track_id            track_name  track_popularity  \
# 0  3AJwUDP919kvQ9QcozQPxg                Yellow                91
# 1  2m1hi0nfMR9vdGC8UcrnwU  All The Small Things                84
# 2  3y4LxiYMgDl4RethdzpmNe               Breathe                69
# 3  60a0Rd6pjrkxjPbaKzXjfq            In the End                88
# 4  62bOmKYxYg7dhrC6gH9vFn           Bye Bye Bye                74
#
#                            album               artist_id  artist_name  \
# 0                     Parachutes  4gzpq5DPGxSnKTe4SA8HAU     Coldplay
# 1             Enema Of The State  6FBDaR13swtiWwGhX1WQsP    blink-182
# 2                        Breathe  25NQNriVT2YbSW80ILRWJa   Faith Hill
# 3  Hybrid Theory (Bonus Edition)  6XyY86QOPPrYVGvF9ch6wz  Linkin Park
# 4            No Strings Attached  6Ff53KvcvAj5U7Z1vojB5o       *NSYNC
#
#                                        artist_genres  artist_popularity  ...  \
# 0                          ['permanent wave', 'pop']                 86  ...
# 1  ['alternative metal', 'modern rock', 'pop punk...                 75  ...
# 2  ['contemporary country', 'country', 'country d...                 61  ...
# 3  ['alternative metal', 'nu metal', 'post-grunge...                 83  ...
# 4                   ['boy band', 'dance pop', 'pop']                 65  ...
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -7.227   1.0       0.0281       0.00239          0.000121    0.2340
# 1    -4.918   1.0       0.0488       0.01030          0.000000    0.6120
# 2    -9.007   1.0       0.0290       0.17300          0.000000    0.2510
# 3    -5.870   0.0       0.0584       0.00958          0.000000    0.2090
# 4    -4.843   0.0       0.0479       0.03100          0.001200    0.0821
#
#    valence    tempo  duration_ms  time_signature
# 0    0.285  173.372     266773.0             4.0
# 1    0.684  148.726     167067.0             4.0
# 2    0.278  136.859     250547.0             4.0
# 3    0.400  105.143     216880.0             4.0
# 4    0.861  172.638     200400.0             4.0
#
# [5 rows x 23 columns]

# %%
playlist_df.dropna(inplace=True) #drop all null values
playlist_df.columns
# Out:
# Index(['playlist_url', 'year', 'track_id', 'track_name', 'track_popularity',
#        'album', 'artist_id', 'artist_name', 'artist_genres',
#        'artist_popularity', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
cat_cols = ['playlist_url', 'album', 'artist_name', 'artist_genres', 'artist_id', 'track_name', 'track_id']
num_cols = ['year', 'track_popularity', 'artist_id', 'danceability', 'energy', 'key', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_ms', 'time_signature']

# %%
playlist_df_cat = playlist_df[cat_cols]
playlist_df_cat.head()
# Out:
#                                         playlist_url  \
# 0  https://open.spotify.com/playlist/37i9dQZF1DWU...
# 1  https://open.spotify.com/playlist/37i9dQZF1DWU...
# 2  https://open.spotify.com/playlist/37i9dQZF1DWU...
# 3  https://open.spotify.com/playlist/37i9dQZF1DWU...
# 4  https://open.spotify.com/playlist/37i9dQZF1DWU...
#
#                            album  artist_name  \
# 0                     Parachutes     Coldplay
# 1             Enema Of The State    blink-182
# 2                        Breathe   Faith Hill
# 3  Hybrid Theory (Bonus Edition)  Linkin Park
# 4            No Strings Attached       *NSYNC
#
#                                        artist_genres               artist_id  \
# 0                          ['permanent wave', 'pop']  4gzpq5DPGxSnKTe4SA8HAU
# 1  ['alternative metal', 'modern rock', 'pop punk...  6FBDaR13swtiWwGhX1WQsP
# 2  ['contemporary country', 'country', 'country d...  25NQNriVT2YbSW80ILRWJa
# 3  ['alternative metal', 'nu metal', 'post-grunge...  6XyY86QOPPrYVGvF9ch6wz
# 4                   ['boy band', 'dance pop', 'pop']  6Ff53KvcvAj5U7Z1vojB5o
#
#              track_name                track_id
# 0                Yellow  3AJwUDP919kvQ9QcozQPxg
# 1  All The Small Things  2m1hi0nfMR9vdGC8UcrnwU
# 2               Breathe  3y4LxiYMgDl4RethdzpmNe
# 3            In the End  60a0Rd6pjrkxjPbaKzXjfq
# 4           Bye Bye Bye  62bOmKYxYg7dhrC6gH9vFn

# %% [markdown]
# Lets look into artist_genres a bit more and see if we can change it into a numerical factor for our analysis. I expect some genres are more popular then others such as country vs pop.

# %%
genres = []

for index, row in playlist_df_cat.iterrows():
    print(row['artist_genres'])
    break 
    # Find a way to get all unique genres and provide them a number
    # To categorize them
# Out:
# ['permanent wave', 'pop']

# %%
playlist_df.drop(cat_cols[:-1], axis=1, inplace=True)
playlist_df.head()
# Out:
#    year                track_id  track_popularity  artist_popularity  \
# 0  2000  3AJwUDP919kvQ9QcozQPxg                91                 86
# 1  2000  2m1hi0nfMR9vdGC8UcrnwU                84                 75
# 2  2000  3y4LxiYMgDl4RethdzpmNe                69                 61
# 3  2000  60a0Rd6pjrkxjPbaKzXjfq                88                 83
# 4  2000  62bOmKYxYg7dhrC6gH9vFn                74                 65
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.429   0.661  11.0    -7.227   1.0       0.0281       0.00239
# 1         0.434   0.897   0.0    -4.918   1.0       0.0488       0.01030
# 2         0.529   0.496   7.0    -9.007   1.0       0.0290       0.17300
# 3         0.556   0.864   3.0    -5.870   0.0       0.0584       0.00958
# 4         0.610   0.926   8.0    -4.843   0.0       0.0479       0.03100
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000121    0.2340    0.285  173.372     266773.0             4.0
# 1          0.000000    0.6120    0.684  148.726     167067.0             4.0
# 2          0.000000    0.2510    0.278  136.859     250547.0             4.0
# 3          0.000000    0.2090    0.400  105.143     216880.0             4.0
# 4          0.001200    0.0821    0.861  172.638     200400.0             4.0

# %%
X_train, X_test, y_train, y_test = train_test_split(playlist_df.drop(['track_popularity', 'track_id'], axis=1),playlist_df['track_popularity'], test_size=0.2)

# %%
print('Train Shapes:', X_train.shape, y_train.shape)
print('Test Shapes:', X_test.shape, y_test.shape)
# Out:
# Train Shapes: (1839, 15) (1839,)
# Test Shapes: (460, 15) (460,)

# %% [markdown]
# #### Creating a Basemodel for Linear Regression and Decision Tree

# %%
lin_reg = LinearRegression()
cross_val_score(lin_reg, X_train, y_train, cv=3)
# Out:
# array([0.07133817, 0.10767511, 0.09865124])

# %%
tree_reg = DecisionTreeRegressor()
cross_val_score(tree_reg, X_train, y_train, cv=3)
# Out:
# array([-0.67316935, -0.37539043, -0.58830187])

# %%
# Hyperparamter tunning, Finding a way to significally improve model
